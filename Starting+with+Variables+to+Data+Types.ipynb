# %% [markdown]
# # First Code

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# # Variables

# %%
message = "Hello world"
number = 42

# %%
message
# Out:
# 'Hello world'

# %%
number
# Out:
# 42

# %%
age = 23

# %%
23age = 23
# Out:
#   Input In [7]
#     23age = 23
#       ^
# SyntaxError: invalid syntax

# %%
age23 = 23

# %%
Age = 23

# %%
age_of_men = 23

# %%
Age = 45

# %%
age = 23

# %%
Age
# Out:
# 45

# %%
age
# Out:
# 23

# %%
four = "ggg"

# %%
four
# Out:
# 'ggg'

# %%
age = 34

# %% [markdown]
# # Data Types

# %% [markdown]
# Main types of data: integer, float, string/object, boolian

# %%
age = 24

# %%
type(age)
# Out:
# int

# %%
minus = -45

# %%
type(minus)
# Out:
# int

# %%
income = -230.45

# %%
type(income)
# Out:
# float

# %%
"Hello world"
# Out:
# 'Hello world'

# %%
"3454354"
# Out:
# '3454354'

# %%
type("Hello world")
# Out:
# str

# %%
type("3454354")
# Out:
# str

# %%
fun = False

# %%
type(fun)
# Out:
# bool

# %% [markdown]
# # Type Conversion

# %%
type(age)
# Out:
# int

# %%
float_age = float(age)

# %%
type(float_age)
# Out:
# float

# %%
float_age
# Out:
# 24.0

# %%
int_income = int(income)

# %%
type(int_income)
# Out:
# int

# %%
int_income
# Out:
# -230

# %%
age_father = "56"

# %%
type(age_father)
# Out:
# str

# %%
int_age_father = int(age_father)

# %%
type(int_age_father)
# Out:
# int

# %%
int_age_father
# Out:
# 56

# %%
age_brother = 34

# %%
total_age = int_age_father + age_brother

# %%
total_age
# Out:
# 90

# %%
str_age_brother = str(age_brother)

# %%
str_age_brother
# Out:
# '34'

# %%
age_father_brother = age_father + "," + str_age_brother

# %%
age_father_brother
# Out:
# '56,34'
